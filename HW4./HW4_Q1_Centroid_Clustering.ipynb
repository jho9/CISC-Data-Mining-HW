# %%
import numpy as np
import pandas as pd
import math
from scipy.io import arff
import matplotlib.pyplot as plt

# %%
def get_distances(X_train, indices):
    return (np.linalg.norm(X_train - indices, axis = 1))

# %%
def K_means_centroid(list_of_Ks,k):
    start = 0
    stop = k
    list_of_total_acc = []
    for j in range(25):
        #df = pd.DataFrame()
        print("This is j of: ", j, "out of 24")
        print("Start is: ", start)
        print("Stop is:  ", stop)
        counter = 1
        temp = []
        indices = data.iloc[list_of_Ks[start:stop],:].index
        centroid = pd.DataFrame(temp)
        centroid = X_train.iloc[indices]
        prev_centroid = pd.DataFrame(temp)

        #print(centroid)
        while ((prev_centroid.equals(centroid)) == False) and counter < 50:
            list_of_distances = []
            difference_of_start_stop = stop - start
            print("Counter is going through this: ", counter)
            for i in range(difference_of_start_stop):
            #Distnace Function: 
                #get_distances(X_train,centroid.iloc[i])
                list_of_distances.append(get_distances(X_train,centroid.iloc[i]))

            distances_df = pd.DataFrame(list_of_distances).T

            #print(distances_df)

            list_of_labels = []
            #print(distances_df.shape)
            for i in range(distances_df.shape[0]):
                #print(i)
                #print("Checking_idxmin")
                #print(distances_df.iloc[i])
                #print("Checked Iloc")
                #print(distances_df.iloc[i].idxmin())
                list_of_labels.append(distances_df.iloc[i].idxmin())
            #print(list_of_labels)
            distances_df['Label'] = list_of_labels
            #val1 = (distances_df['Label'][distances_df['Label'] == 0]).count()
            #val2 = (distances_df['Label'][distances_df['Label'] == 1]).count()
            #val3 = (distances_df['Label'][distances_df['Label'] == 2]).count()
            #print(val1)
            #print(val2)
            #print(val3)
            #print(val1+val2+val3)

            list_of_new_centroids = []
            for i in range(difference_of_start_stop):
                list_of_new_centroids.append(X_train.iloc[distances_df[distances_df['Label'] == i].index].mean())

            prev_centroid = centroid
            #print(list_of_new_centroids)
            #print(centroid)
            #print(list_of_new_centroids)
            centroid = pd.DataFrame(temp)
            centroid = pd.DataFrame(list_of_new_centroids)
            #print(prev_centroid)
            #print(centroid)
            counter = counter + 1

        #print(centroid)

        #get_distances(df[], centroid)
        list_of_vals =[]
        for i in range(difference_of_start_stop):
            list_of_vals.append(((get_distances(X_train.iloc[distances_df[distances_df['Label'] == i].index], centroid.iloc[i]))**2).sum())

        total =sum(list_of_vals)
        print("This is the individual distance value: ")
        print(total)

        start = start + k
        stop = stop + k
        list_of_total_acc.append(total)
    avg_accur = sum(list_of_total_acc)/len(list_of_total_acc)
    print("This is the avg:")
    print(avg_accur)
    sum_of_acc = 0
    std = 0
    print("This is the std")
    for i in range(len(list_of_total_acc)):
        sum_of_acc = sum_of_acc +(list_of_total_acc[i] - avg_accur)**2
    std = math.sqrt((sum_of_acc)/len(list_of_total_acc))
    print(std)
    return avg_accur, std

# %%
list_of_Ks = [775, 1020, 200, 127, 329, 1626, 1515, 651, 658, 328, 1160, 108, 422, 88, 105, 261, 212,
1941, 1724, 704, 1469, 635, 867, 1187, 445, 222, 1283, 1288, 1766, 1168, 566, 1812, 214,
53, 423, 50, 705, 1284, 1356, 996, 1084, 1956, 254, 711, 1997, 1378, 827, 1875, 424,
1790, 633, 208, 1670, 1517, 1902, 1476, 1716, 1709, 264, 1, 371, 758, 332, 542, 672, 483,
65, 92, 400, 1079, 1281, 145, 1410, 664, 155, 166, 1900, 1134, 1462, 954, 1818, 1679,
832, 1627, 1760, 1330, 913, 234, 1635, 1078, 640, 833, 392, 1425, 610, 1353, 1772, 908,
1964, 1260, 784, 520, 1363, 544, 426, 1146, 987, 612, 1685, 1121, 1740, 287, 1383, 1923,
1665, 19, 1239, 251, 309, 245, 384, 1306, 786, 1814, 7, 1203, 1068, 1493, 859, 233, 1846,
1119, 469, 1869, 609, 385, 1182, 1949, 1622, 719, 643, 1692, 1389, 120, 1034, 805, 266,
339, 826, 530, 1173, 802, 1495, 504, 1241, 427, 1555, 1597, 692, 178, 774, 1623, 1641,
661, 1242, 1757, 553, 1377, 1419, 306, 1838, 211, 356, 541, 1455, 741, 583, 1464, 209,
1615, 475, 1903, 555, 1046, 379, 1938, 417, 1747, 342, 1148, 1697, 1785, 298, 1485,
945, 1097, 207, 857, 1758, 1390, 172, 587, 455, 1690, 1277, 345, 1166, 1367, 1858, 1427,
1434, 953, 1992, 1140, 137, 64, 1448, 991, 1312, 1628, 167, 1042, 1887, 1825, 249, 240,
524, 1098, 311, 337, 220, 1913, 727, 1659, 1321, 130, 1904, 561, 1270, 1250, 613, 152,
1440, 473, 1834, 1387, 1656, 1028, 1106, 829, 1591, 1699, 1674, 947, 77, 468, 997, 611,
1776, 123, 979, 1471, 1300, 1007, 1443, 164, 1881, 1935, 280, 442, 1588, 1033, 79, 1686,
854, 257, 1460, 1380, 495, 1701, 1611, 804, 1609, 975, 1181, 582, 816, 1770, 663, 737,
1810, 523, 1243, 944, 1959, 78, 675, 135, 1381, 1472]

# %%
def main():
    path = ('segment.arff')
    rawdata = arff.loadarff(path)
    data = pd.DataFrame(rawdata[0])
    X_values = data.iloc[:,:19]
    X_train = (X_values- X_values.mean())/(X_values.std())
    X_train = X_train.dropna(axis = 1)
    list_of_acc = []
    for k in range(1, 13):
        list_of_acc.append(K_means_centroid(list_of_Ks, k))
    results = pd.DataFrame(list_of_acc)
    results.columns = ['Mean', 'std']
    results['+/- Confidence'] = results['std'] * 2
    results['+ Confidence'] = results['Mean'] + results['+/- Confidence']
    results['- Confidence'] = results['Mean'] - results['+/- Confidence']
    results['k'] = range(1,13)
    order = ['k', 'Mean', '- Confidence', '+ Confidence']
    print(results[order])
    #plt.plot(range(1,13), results['Acc'])
    #plt.plot(range(1,13), results['+ Confidence'])
    #plt.plot(range(1,13), results['- Confidence'])

    #plt.errorbar(range(1,13), results['Acc'], yerr=results['+/- Confidence'], fmt='--o')
    #axes = plt.gca()
    #axes.set_ylim([0,80000])
    #plt.errorbar(range(1,13), results['Acc'], yerr=results['+/- Confidence'], fmt='--o')
    #axes = plt.gca()
    #axes.set_ylim([0,60000])

# %%
main()
# Out:
# This is j of:  0 out of 24
# Start is:  0
# Stop is:   1
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  1 out of 24
# Start is:  1
# Stop is:   2
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  2 out of 24
# Start is:  2
# Stop is:   3
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  3 out of 24
# Start is:  3
# Stop is:   4
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  4 out of 24
# Start is:  4
# Stop is:   5
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  5 out of 24
# Start is:  5
# Stop is:   6
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  6 out of 24
# Start is:  6
# Stop is:   7
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  7 out of 24
# Start is:  7
# Stop is:   8
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  8 out of 24
# Start is:  8
# Stop is:   9
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  9 out of 24
# Start is:  9
# Stop is:   10
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  10 out of 24
# Start is:  10
# Stop is:   11
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  11 out of 24
# Start is:  11
# Stop is:   12
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  12 out of 24
# Start is:  12
# Stop is:   13
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  13 out of 24
# Start is:  13
# Stop is:   14
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  14 out of 24
# Start is:  14
# Stop is:   15
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  15 out of 24
# Start is:  15
# Stop is:   16
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  16 out of 24
# Start is:  16
# Stop is:   17
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  17 out of 24
# Start is:  17
# Stop is:   18
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  18 out of 24
# Start is:  18
# Stop is:   19
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  19 out of 24
# Start is:  19
# Stop is:   20
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  20 out of 24
# Start is:  20
# Stop is:   21
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  21 out of 24
# Start is:  21
# Stop is:   22
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  22 out of 24
# Start is:  22
# Stop is:   23
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  23 out of 24
# Start is:  23
# Stop is:   24
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is j of:  24 out of 24
# Start is:  24
# Stop is:   25
# Counter is going through this:  1
# Counter is going through this:  2
# This is the individual distance value:
# 41561.999999999796
# This is the avg:
# 41561.999999999774
# This is the std
# 2.1827872842550278e-11
# This is j of:  0 out of 24
# Start is:  0
# Stop is:   2
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 28761.469960194365
# This is j of:  1 out of 24
# Start is:  2
# Stop is:   4
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 28761.479165964876
# This is j of:  2 out of 24
# Start is:  4
# Stop is:   6
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# This is the individual distance value:
# 28761.469960194365
# This is j of:  3 out of 24
# Start is:  6
# Stop is:   8
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# This is the individual distance value:
# 29016.494169987287
# This is j of:  4 out of 24
# Start is:  8
# Stop is:   10
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.469960194365
# This is j of:  5 out of 24
# Start is:  10
# Stop is:   12
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# This is the individual distance value:
# 39340.01433612214
# This is j of:  6 out of 24
# Start is:  12
# Stop is:   14
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# This is the individual distance value:
# 28761.469960194365
# This is j of:  7 out of 24
# Start is:  14
# Stop is:   16
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 28761.469960194365
# This is j of:  8 out of 24
# Start is:  16
# Stop is:   18
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.469960194365
# This is j of:  9 out of 24
# Start is:  18
# Stop is:   20
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 28761.469960194365
# This is j of:  10 out of 24
# Start is:  20
# Stop is:   22
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 28761.469960194365
# This is j of:  11 out of 24
# Start is:  22
# Stop is:   24
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.479165964876
# This is j of:  12 out of 24
# Start is:  24
# Stop is:   26
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# This is the individual distance value:
# 28761.469960194365
# This is j of:  13 out of 24
# Start is:  26
# Stop is:   28
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.479165964876
# This is j of:  14 out of 24
# Start is:  28
# Stop is:   30
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.469960194365
# This is j of:  15 out of 24
# Start is:  30
# Stop is:   32
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 28761.469960194365
# This is j of:  16 out of 24
# Start is:  32
# Stop is:   34
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 28761.469960194365
# This is j of:  17 out of 24
# Start is:  34
# Stop is:   36
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# This is the individual distance value:
# 28761.469960194365
# This is j of:  18 out of 24
# Start is:  36
# Stop is:   38
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# This is the individual distance value:
# 28761.469960194365
# This is j of:  19 out of 24
# Start is:  38
# Stop is:   40
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# This is the individual distance value:
# 28761.469960194365
# This is j of:  20 out of 24
# Start is:  40
# Stop is:   42
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# This is the individual distance value:
# 29016.494169987287
# This is j of:  21 out of 24
# Start is:  42
# Stop is:   44
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 28761.469960194365
# This is j of:  22 out of 24
# Start is:  44
# Stop is:   46
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 28761.479165964876
# This is j of:  23 out of 24
# Start is:  46
# Stop is:   48
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# This is the individual distance value:
# 28761.469960194365
# This is j of:  24 out of 24
# Start is:  48
# Stop is:   50
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 28761.469960194365
# This is the avg:
# 29205.015144938185
# This is the std
# 2069.9504103841455
# This is j of:  0 out of 24
# Start is:  0
# Stop is:   3
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# This is the individual distance value:
# 24505.72100001138
# This is j of:  1 out of 24
# Start is:  3
# Stop is:   6
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# This is the individual distance value:
# 24390.938034742496
# This is j of:  2 out of 24
# Start is:  6
# Stop is:   9
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 23652.304624279153
# This is j of:  3 out of 24
# Start is:  9
# Stop is:   12
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# This is the individual distance value:
# 27347.337053041283
# This is j of:  4 out of 24
# Start is:  12
# Stop is:   15
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 27080.143340201543
# This is j of:  5 out of 24
# Start is:  15
# Stop is:   18
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24505.72100001138
# This is j of:  6 out of 24
# Start is:  18
# Stop is:   21
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# This is the individual distance value:
# 24505.72100001138
# This is j of:  7 out of 24
# Start is:  21
# Stop is:   24
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# This is the individual distance value:
# 24505.72100001138
# This is j of:  8 out of 24
# Start is:  24
# Stop is:   27
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# This is the individual distance value:
# 24505.72100001138
# This is j of:  9 out of 24
# Start is:  27
# Stop is:   30
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# This is the individual distance value:
# 24585.46424060269
# This is j of:  10 out of 24
# Start is:  30
# Stop is:   33
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# This is the individual distance value:
# 24505.72100001138
# This is j of:  11 out of 24
# Start is:  33
# Stop is:   36
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# This is the individual distance value:
# 24505.72100001138
# This is j of:  12 out of 24
# Start is:  36
# Stop is:   39
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 23657.74164662737
# This is j of:  13 out of 24
# Start is:  39
# Stop is:   42
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# This is the individual distance value:
# 23652.304624279153
# This is j of:  14 out of 24
# Start is:  42
# Stop is:   45
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# This is the individual distance value:
# 24505.72100001138
# This is j of:  15 out of 24
# Start is:  45
# Stop is:   48
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# This is the individual distance value:
# 23652.304624279153
# This is j of:  16 out of 24
# Start is:  48
# Stop is:   51
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# This is the individual distance value:
# 24505.72100001138
# This is j of:  17 out of 24
# Start is:  51
# Stop is:   54
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24507.038843231225
# This is j of:  18 out of 24
# Start is:  54
# Stop is:   57
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# This is the individual distance value:
# 23652.304624279153
# This is j of:  19 out of 24
# Start is:  57
# Stop is:   60
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 25371.753075000302
# This is j of:  20 out of 24
# Start is:  60
# Stop is:   63
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24505.72100001138
# This is j of:  21 out of 24
# Start is:  63
# Stop is:   66
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24505.72100001138
# This is j of:  22 out of 24
# Start is:  66
# Stop is:   69
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24505.72100001138
# This is j of:  23 out of 24
# Start is:  69
# Stop is:   72
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# This is the individual distance value:
# 23652.304624279153
# This is j of:  24 out of 24
# Start is:  72
# Stop is:   75
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 24505.72100001138
# This is the avg:
# 24551.052494199626
# This is the std
# 889.5228498500859
# This is j of:  0 out of 24
# Start is:  0
# Stop is:   4
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 20018.646763843626
# This is j of:  1 out of 24
# Start is:  4
# Stop is:   8
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# This is the individual distance value:
# 23269.54898632146
# This is j of:  2 out of 24
# Start is:  8
# Stop is:   12
# ...
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# This is the individual distance value:
# 20018.64676384363
# This is j of:  12 out of 24
# Start is:  48
# Stop is:   52
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 20018.71245178648
# This is j of:  13 out of 24
# Start is:  52
# Stop is:   56
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# This is the individual distance value:
# 20018.71245178648
# This is j of:  14 out of 24
# Start is:  56
# Stop is:   60
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# This is the individual distance value:
# 21213.701856646345
# This is j of:  15 out of 24
# Start is:  60
# Stop is:   64
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# Counter is going through this:  32
# Counter is going through this:  33
# Counter is going through this:  34
# Counter is going through this:  35
# Counter is going through this:  36
# Counter is going through this:  37
# Counter is going through this:  38
# Counter is going through this:  39
# Counter is going through this:  40
# Counter is going through this:  41
# Counter is going through this:  42
# Counter is going through this:  43
# Counter is going through this:  44
# Counter is going through this:  45
# Counter is going through this:  46
# Counter is going through this:  47
# Counter is going through this:  48
# Counter is going through this:  49
# This is the individual distance value:
# 23862.988443592352
# This is j of:  16 out of 24
# Start is:  64
# Stop is:   68
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 20018.71245178648
# This is j of:  17 out of 24
# Start is:  68
# Stop is:   72
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# This is the individual distance value:
# 20018.64676384363
# This is j of:  18 out of 24
# Start is:  72
# Stop is:   76
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# This is the individual distance value:
# 20018.71245178648
# This is j of:  19 out of 24
# Start is:  76
# Stop is:   80
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# This is the individual distance value:
# 20018.61014862977
# This is j of:  20 out of 24
# Start is:  80
# Stop is:   84
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# This is the individual distance value:
# 23272.214453276545
# This is j of:  21 out of 24
# Start is:  84
# Stop is:   88
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# Counter is going through this:  27
# Counter is going through this:  28
# Counter is going through this:  29
# Counter is going through this:  30
# Counter is going through this:  31
# This is the individual distance value:
# 20028.988889762866
# This is j of:  22 out of 24
# Start is:  88
# Stop is:   92
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 23801.146864674607
# This is j of:  23 out of 24
# Start is:  92
# Stop is:   96
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# Counter is going through this:  21
# Counter is going through this:  22
# Counter is going through this:  23
# Counter is going through this:  24
# Counter is going through this:  25
# Counter is going through this:  26
# This is the individual distance value:
# 21213.70185664635
# This is j of:  24 out of 24
# Start is:  96
# Stop is:   100
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# This is the individual distance value:
# 20018.71245178648
# This is the avg:
# 21157.862902719666
# This is the std
# 1566.5007325433144
# This is j of:  0 out of 24
# Start is:  0
# Stop is:   5
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 19634.31800404455
# This is j of:  1 out of 24
# Start is:  5
# Stop is:   10
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 19634.842454732505
# This is j of:  2 out of 24
# Start is:  10
# Stop is:   15
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# Counter is going through this:  18
# Counter is going through this:  19
# Counter is going through this:  20
# This is the individual distance value:
# 18862.12947343693
# This is j of:  3 out of 24
# Start is:  15
# Stop is:   20
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# This is the individual distance value:
# 19690.97088340169
# This is j of:  4 out of 24
# Start is:  20
# Stop is:   25
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# This is the individual distance value:
# 15818.633209988151
# This is j of:  5 out of 24
# Start is:  25
# Stop is:   30
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# Counter is going through this:  15
# Counter is going through this:  16
# Counter is going through this:  17
# This is the individual distance value:
# 15818.633209988151
# This is j of:  6 out of 24
# Start is:  30
# Stop is:   35
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# Counter is going through this:  13
# Counter is going through this:  14
# This is the individual distance value:
# 19690.970883401686
# This is j of:  7 out of 24
# Start is:  35
# Stop is:   40
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
# Counter is going through this:  7
# Counter is going through this:  8
# Counter is going through this:  9
# Counter is going through this:  10
# Counter is going through this:  11
# Counter is going through this:  12
# This is the individual distance value:
# 18862.64301066714
# This is j of:  8 out of 24
# Start is:  40
# Stop is:   45
# Counter is going through this:  1
# Counter is going through this:  2
# Counter is going through this:  3
# Counter is going through this:  4
# Counter is going through this:  5
# Counter is going through this:  6
